# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0,100)

y1 = x**8
y2 = x**9

plt.semilogy(x, y1 ,'+r-', x, y2, 'xb-')
plt.xlabel('x')
plt.ylabel('log y')
plt.grid()
plt.show()
